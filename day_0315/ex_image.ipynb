# %%
from PIL import Image

# %%
file='./image/다운로드.jpg'

# %%
try:
    im_data=Image.open(file)
except Exception as e:
    print(e)

# %%
type(im_data)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
im_data.width, im_data.height, im_data.size
# Out:
# (357, 141, (357, 141))

# %%
im_data
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=357x141>

# %%
# 실제 이미지 raw 데이터 16진수 표시
im_data.tobytes()
# Out:
# b"
# ...

# %%
# 이미지 보기 => 이미지 관련 프로그램
im_data.show()

# %%
g_img=im_data.convert('L')
